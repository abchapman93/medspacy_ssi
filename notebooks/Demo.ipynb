# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, "..")

# %% [markdown]
# # Load the model

# %%
import medspacy_ssi

# %%
import warnings
warnings.filterwarnings("ignore")
nlp = medspacy_ssi.load()

# %%
nlp.pipe_names
# Out:
# ['sentencizer',
#  'target_matcher',
#  'context',
#  'sectionizer',
#  'document_classifier']

# %% [markdown]
# # Read in text and process

# %%
filepath = "./sample_report.txt"

# %%
with open(filepath) as f:
    text = f.read()

# %%
doc = nlp(text)

# %%
doc._.document_classification
# Out:
# 'POS'

# %%
from medspacy.visualization import visualize_ent

# %%
visualize_ent(doc)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">CT ABD &amp;
# <mark class="entity" style="background: #7f7f7f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     PELVIS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  WITH CONTRAST </br> ~ Reason:
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Evaluate for
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">INDICATION</span>
# </mark>
#
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abscess
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
# /
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fluid collection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
#
# <mark class="entity" style="background: #7f7f7f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     collection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  and drain position.</br> ~ Admitting Diagnosis: CHOLECYSTITIS</br>  Contrast: OPTIRAY Amt: 130</br> </br></br> ~
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     UNDERLYING MEDICAL CONDITION:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"><< PAST_MEDICAL_HISTORY >></span>
# </mark>
# </br>  82M s/p open CCY and
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     biloma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
#  drainage with  drains in place--now draining</br>  purulent fluid.</br> ~
# <mark class="entity" style="background: #dee0e3; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     REASON FOR THIS EXAMINATION:
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem"><< REASON_FOR_EXAMINATION >></span>
# </mark>
# </br>
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Evaluate for
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">INDICATION</span>
# </mark>
#
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     abscess
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
# /
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fluid collection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
#
# <mark class="entity" style="background: #7f7f7f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     collection
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  and drain position.</br>
# <mark class="entity" style="background: #2ca02c; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     No contraindications for IV contrast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PSEUDONEG</span>
# </mark>
# </br> </br></br> ~ WET READ: MLHh </br>
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Multiloculated communicating fluid
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
#
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     collections
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
#
# <mark class="entity" style="background: #7f7f7f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     collections
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  in GB fossa (w/ Surgicel),</br>  perihepatic space, and R abd/pelvis.  Some of these have characteristics</br>
# <mark class="entity" style="background: #bcbd22; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     concerning for
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PROBABLE_EXISTENCE</span>
# </mark>
#
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     hematoma
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
# /superinfx.</br>  R
# <mark class="entity" style="background: #7f7f7f; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     rectus abdominis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ANATOMY</span>
# </mark>
#  edema and small IM
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fluid collections
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FLUID_COLLECTION</span>
# </mark>
# , cannot
# <mark class="entity" style="background: #d62728; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     r/o
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">INDICATION</span>
# </mark>
#  infx.</br>  Malpositioned  drains, which course through
# <mark class="entity" style="background: #8c564b; padding: 0.45em 0.6em

# %%
doc.ents
# Out:
# (abscess,
#  fluid collection,
#  biloma,
#  abscess,
#  fluid collection,
#  Multiloculated communicating fluid,
#  collections,
#  hematoma,
#  fluid collections,
#  collections,
#  Multiloculated fluid,
#  collections,
#  fluid collections,
#  biloma,
#  abscess,
#  abscess,
#  fluid collection,
#  fluid collections,
#  collection,
#  collections,
#  collection,
#  collection,
#  collection,
#  fluid collection,
#  fluid collection,
#  fluid collection,
#  collection,
#  fluid collection,
#  collections,
#  fluid collection,
#  collection,
#  fluid collections,
#  loculations,
#  collections,
#  collection,
#  collection)

# %%
for ent in doc.ents:
    anatomy = ent._.anatomical_location
    if anatomy is not None:
        print(ent, anatomy, sep=" --> ")
# Out:
# abscess --> collection

# %%
from medspacy.context import DEFAULT_ATTRS

# %%
DEFAULT_ATTRS
# Out:
# {'NEGATED_EXISTENCE': {'is_negated': True},
#  'POSSIBLE_EXISTENCE': {'is_uncertain': True},
#  'HISTORICAL': {'is_historical': True},
#  'HYPOTHETICAL': {'is_hypothetical': True},
#  'FAMILY': {'is_family': True}}

# %%
import medspacy_ssi

# Load the model
nlp = medspacy_ssi.load()

# Process text
doc = nlp("Reason: Evaluate for abdominal abscess/fluid collection and drain position.")

# View entities and their anatomical locations
print(doc.ents)

for ent in doc.ents:
    anatomy = ent._.anatomical_location
    if anatomy is not None:
        print(ent, anatomy, sep=" --> ")

# Document classification
print(doc._.document_classification) # "NEG"

# Visualize the full output using medspaCy
from medspacy.visualization import visualize_ent
visualize_ent(doc)
